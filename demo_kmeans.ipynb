# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA, TruncatedSVD

from dataclasses import dataclass
from typing import Any, Dict, Iterable, List, Optional, Tuple, Union, Optional
import pyodbc

import math
import re
import warnings

print("hello world")
# Out:
# hello world

# %%
# read xlsx into pandas
df = pd.read_excel("../isec_data/df_sample_100k.xlsx", engine="openpyxl", index_col=0)
df.iloc[:10]
# Out:
#     serial_no acct_opn_dt                 name        dob  age gender  \
# 0  9007305054  2017-08-19         SHARAD SINGH 1995-02-02   31      M
# 1  9007305091  2017-08-18        HIRDESH SINGH 1944-02-10   82      F
# 2  9007305145  2017-10-07       NIRANJAN KUMAR 1990-02-15   36      M
# 3  9007305200  2017-07-18      ABHISHEK SHARMA 1997-09-20   28      M
# 4  9007305236  2017-08-09  ASHOK KUMAR LAVANIA 1946-12-27   79      M
# 5  9007305538  2017-06-02        SURUCHI GUPTA 1988-02-23   38      F
# 6  9007305651  2017-06-27     SHORBAN BANERJEE 1971-12-28   54      F
# 7  9007305877  2017-08-01        SANJEEV GHOSH 1970-03-24   56      M
# 8  9007306867  2017-10-05          NIDHI BEMBI 1994-09-14   31      F
# 9  9007307094  2017-07-25   RUCHI PUNEET GUPTA 1986-06-01   40      F
#
#   marital_status                           email        city          state  \
# 0              Y             95ssharda@gmail.com  RAE BARELI  UTTAR PRADESH
# 1              M       singhvikekkumar@gmail.com  EAST DELHI          DELHI
# 2              N  niranjankumar.singh2@gmail.com       DELHI          DELHI
# 3              Y    abhishekkharma1997@gmail.com   FARIDABAD        HARYANA
# 4              Y            alavania27@gmail.com       DELHI          DELHI
# 5              Y     suruchibansal2388@gmail.com       NOIDA  UTTAR PRADESH
# 6              Y      shorban.banerjee@gmail.com       NOIDA  UTTAR PRADESH
# 7              Y  sanjeev@whitehouseoverseas.com       DELHI          DELHI
# 8              N             bembindhi@gmail.com    LUDHIANA         PUNJAB
# 9              Y         ruchi.skyblue@gmail.com       DHULE    MAHARASHTRA
#
#    ... iai_uccstatus_dt  iai_class_download_run_no iai_modify_dt_run_no  \
# 0  ...              NaN                        NaN                  NaN
# 1  ...              NaN                        NaN                  NaN
# 2  ...              NaN                        NaN                  NaN
# 3  ...              NaN                        NaN                  NaN
# 4  ...              NaN                        NaN                  NaN
# 5  ...              NaN                        NaN                  NaN
# 6  ...              NaN                        NaN                  NaN
# 7  ...              NaN                        NaN                  NaN
# 8  ...              NaN                        NaN                  NaN
# 9  ...              NaN                        NaN                  NaN
#
#   iai_enable_for_dwid iai_bnk_account_flag iai_comm_class_status  \
# 0                 NaN                  NaN                   NaN
# 1                 NaN                  NaN                   NaN
# 2                 NaN                  NaN                   NaN
# 3                 NaN                  NaN                   NaN
# 4                 NaN                  NaN                   NaN
# 5                 NaN                  NaN                   NaN
# 6                 NaN                  NaN                   NaN
# 7                 NaN                  NaN                   NaN
# 8                 NaN                  NaN                   NaN
# 9                 NaN                  NaN                   NaN
#
#   iai_bank_type iai_ifsc_cd iai_bnk_account_flag_changed_dt      match_id
# 0           NaN         NaN                             NaN  8.504297e+09
# 1           NaN         NaN                             NaN  8.504296e+09
# 2           NaN         NaN                             NaN  8.504359e+09
# 3           NaN         NaN                             NaN  8.504258e+09
# 4           NaN         NaN                             NaN  8.504289e+09
# 5           NaN         NaN                             NaN  8.504207e+09
# 6           NaN         NaN                             NaN  8.504231e+09
# 7           NaN         NaN                             NaN  8.504274e+09
# 8           NaN         NaN                             NaN  8.504355e+09
# 9           NaN         NaN                             NaN  8.504266e+09
#
# [10 rows x 170 columns]

# %%
# transform income
df["income"] = df["income_desc"].apply(
    lambda v: (
        int(int(m.group(1)) + int(m.group(2)) / 2)
        if pd.notna(v) and (m := re.search(r"(\d+)\s*LAC\s*TO\s*(\d+)\s*LAC", v, re.I))
        else None
    )
)

# convert datetimes
df_clean = df.loc[:, ~df.columns.to_series().map(lambda c: pd.api.types.is_datetime64_any_dtype(df[c]))].copy()
# drop any columns with all nulls
df_clean = df_clean.dropna(axis=1, how='all')
# drop PII etc.
df_clean = df_clean.drop(columns=["serial_no", "name", "email", "city", "state", "country", "pincode", "income_desc", "sourcing_team", "sourcing_channel", "iaf_publisher", "advisory_team", "dnd_flag", "dnc_flag", "neq_total_assets_million", "peak_asset_val_million", "vertical", "mobile_number", "pan", "bsp_flag", "bank_flag", "ers_mapped", "match_id"], errors="coerce")

df_clean[:10]
# Out:
#    age gender marital_status education_desc occupation_desc ri_flag nri_flag  \
# 0   31      M              Y       GRADUATE  PRIVATE SECTOR       Y        N
# 1   82      F              M         OTHERS       HOUSEWIFE       Y        N
# 2   36      M              N         OTHERS  PRIVATE SECTOR       Y        N
# 3   28      M              Y         OTHERS    PROFESSIONAL       Y        N
# 4   79      M              Y       GRADUATE  PRIVATE SECTOR       Y        N
# 5   38      F              Y       GRADUATE       HOUSEWIFE       Y        N
# 6   54      F              Y       GRADUATE    SELFEMPLOYED       Y        N
# 7   56      M              Y       GRADUATE    SELFEMPLOYED       Y        N
# 8   31      F              N       GRADUATE  PRIVATE SECTOR       Y        N
# 9   40      F              Y         OTHERS       HOUSEWIFE       Y        N
#
#     mf_vertical eq_vertical  no_of_logins  ...  allocated_amt  brokerage_type  \
# 0        ONLINE      ONLINE          28.0  ...            NaN          MSAVER
# 1    VIRTUAL RM      SELECT        1711.0  ...            NaN       FPRMN1001
# 2        ONLINE      ONLINE         765.0  ...            1.0       EMP07007N
# 3        ONLINE      ONLINE          45.0  ...         4778.0          MSAVER
# 4  PWM-PHYSICAL      WEALTH         742.0  ...          189.0       APRM07007
# 5        ONLINE      ONLINE         217.0  ...            NaN       PPSN15015
# 6    VIRTUAL RM      SELECT         567.0  ...          233.0          MSAVER
# 7    VIRTUAL RM      ONLINE         395.0  ...            NaN        PRM05005
# 8        ONLINE      ONLINE        2722.0  ...          550.0       EMS07007N
# 9        ONLINE      ONLINE         283.0  ...            NaN       APRN25025
#
#    grade scheme_code  brokerage_rate  brkg_type  mtf_brkg  income_segment  \
# 0      D     Special            29.0       High      High              PB
# 1      A     Special            10.0        Low       Low              WM
# 2      B     Special             NaN        NaN       NaN              PB
# 3      B     Special            29.0       High      High              WM
# 4      A     Special             7.0        Low       Low             GPC
# 5      A     Special            15.0        Low       Low              PB
# 6      B     Special            29.0       High      High              WM
# 7      A     Special             NaN        NaN       NaN              WM
# 8      B     Special             NaN        NaN       NaN              PB
# 9      A     Special            25.0       High      High              PB
#
#   pincode_affluence  income
# 0               Low     3.0
# 1         Very High     3.0
# 2         Very High    10.0
# 3         Very High     3.0
# 4         Very High    17.0
# 5         Very High     3.0
# 6         Very High    10.0
# 7         Very High    50.0
# 8         Very High    17.0
# 9         Very High     3.0
#
# [10 rows x 32 columns]

# %%
num = df_clean.select_dtypes(include=['number']).columns
cat = df_clean.select_dtypes(include=['object', 'category', 'bool']).columns

pre = ColumnTransformer([
    ("num", Pipeline([("imp", SimpleImputer(strategy="median")), ("scaler", StandardScaler())]), num),
    ("cat", Pipeline([("imp", SimpleImputer(strategy="most_frequent")), ("oh", OneHotEncoder(handle_unknown="ignore"))]), cat)
])
kmeans = KMeans(n_clusters=5, n_init="auto", random_state=20, verbose=1)
kmeans
# Out:
# KMeans(n_clusters=5, random_state=20, verbose=1)

# %%
print([x for x in num.append(cat)])
# Out:
# ['age', 'no_of_logins', 'no_logins_last_30', 'no_logins_last_60', 'no_logins_last_90', 'eq_total_assets', 'neq_total_assets', 'peak_asset_val', 'total_products', 'experian_score', 'mtf_rate', 'allocated_amt', 'brokerage_rate', 'income', 'gender', 'marital_status', 'education_desc', 'occupation_desc', 'ri_flag', 'nri_flag', 'mf_vertical', 'eq_vertical', 'acct_status', 'vertical_disg', 'account_type', 'brokerage_type', 'grade', 'scheme_code', 'brkg_type', 'mtf_brkg', 'income_segment', 'pincode_affluence']

# %%
X = pre.fit_transform(df_clean)
labels = kmeans.fit_predict(X)

Z = PCA(n_components=3, random_state=20).fit_transform(X.toarray() if hasattr(X, "toarray") else X)
out = df_clean.assign(cluster=labels)
out[:10]
# Out:
# Initialization complete
# Iteration 0, inertia 675.0436713103825.
# Iteration 1, inertia 474.84759332859346.
# Iteration 2, inertia 469.58513412146897.
# Converged at iteration 2: strict convergence.
#    age gender marital_status education_desc occupation_desc ri_flag nri_flag  \
# 0   31      M              Y       GRADUATE  PRIVATE SECTOR       Y        N
# 1   82      F              M         OTHERS       HOUSEWIFE       Y        N
# 2   36      M              N         OTHERS  PRIVATE SECTOR       Y        N
# 3   28      M              Y         OTHERS    PROFESSIONAL       Y        N
# 4   79      M              Y       GRADUATE  PRIVATE SECTOR       Y        N
# 5   38      F              Y       GRADUATE       HOUSEWIFE       Y        N
# 6   54      F              Y       GRADUATE    SELFEMPLOYED       Y        N
# 7   56      M              Y       GRADUATE    SELFEMPLOYED       Y        N
# 8   31      F              N       GRADUATE  PRIVATE SECTOR       Y        N
# 9   40      F              Y         OTHERS       HOUSEWIFE       Y        N
#
#     mf_vertical eq_vertical  no_of_logins  ...  brokerage_type  grade  \
# 0        ONLINE      ONLINE          28.0  ...          MSAVER      D
# 1    VIRTUAL RM      SELECT        1711.0  ...       FPRMN1001      A
# 2        ONLINE      ONLINE         765.0  ...       EMP07007N      B
# 3        ONLINE      ONLINE          45.0  ...          MSAVER      B
# 4  PWM-PHYSICAL      WEALTH         742.0  ...       APRM07007      A
# 5        ONLINE      ONLINE         217.0  ...       PPSN15015      A
# 6    VIRTUAL RM      SELECT         567.0  ...          MSAVER      B
# 7    VIRTUAL RM      ONLINE         395.0  ...        PRM05005      A
# 8        ONLINE      ONLINE        2722.0  ...       EMS07007N      B
# 9        ONLINE      ONLINE         283.0  ...       APRN25025      A
#
#    scheme_code brokerage_rate  brkg_type  mtf_brkg  income_segment  \
# 0      Special           29.0       High      High              PB
# 1      Special           10.0        Low       Low              WM
# 2      Special            NaN        NaN       NaN              PB
# 3      Special           29.0       High      High              WM
# 4      Special            7.0        Low       Low             GPC
# 5      Special           15.0        Low       Low              PB
# 6      Special           29.0       High      High              WM
# 7      Special            NaN        NaN       NaN              WM
# 8      Special            NaN        NaN       NaN              PB
# 9      Special           25.0       High      High              PB
#
#    pincode_affluence income  cluster
# 0                Low    3.0        1
# 1          Very High    3.0        1
# 2          Very High   10.0        1
# 3          Very High    3.0        1
# 4          Very High   17.0        3
# 5          Very High    3.0        1
# 6          Very High   10.0        1
# 7          Very High   50.0        0
# 8          Very High   17.0        1
# 9          Very High    3.0        1
#
# [10 rows x 33 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Z[:, 0], Z[:, 1], Z[:, 2], c=labels, s=10, cmap="Pastel1")
plt.title("KMeans Clusters (PCA 3D)")
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
plt.show()

# %%
import plotly.express as px
import pandas as pd

df_plot = pd.DataFrame({
    "PC1": Z[:, 0],
    "PC2": Z[:, 1],
    "PC3": Z[:, 2],
    "cluster": labels.astype(str)
})

fig = px.scatter_3d(
    df_plot, x="PC1", y="PC2", z="PC3",
    color="cluster",
    opacity=0.8
)
fig.update_traces(marker=dict(size=3))
fig.update_layout(title="KMeans Clusters (PCA 3D)")
fig.show()

# %%
X_for_kmeans = X
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Use PCA if dense; TruncatedSVD if sparse (works like PCA for visualization)
is_sparse = hasattr(X_for_kmeans, "tocsr") or "scipy.sparse" in str(type(X_for_kmeans)).lower()
Reducer = TruncatedSVD if is_sparse else PCA

reducer2 = Reducer(n_components=2, random_state=20)
reducer3 = Reducer(n_components=3, random_state=20)

X2 = reducer2.fit_transform(X_for_kmeans)
X3 = reducer3.fit_transform(X_for_kmeans)

# IMPORTANT: transform centers with the SAME fitted reducer2
C2 = reducer2.transform(centers)

# sample for the 5th plot (keeps it fast)
n = X2.shape[0]
sample_n = min(20000, n)
idx = np.random.default_rng(20).choice(n, size=sample_n, replace=False)

# -----------------------------
# 5 subplots in one row
# -----------------------------
fig, axes = plt.subplots(1, 5, figsize=(26, 5))

def sc(ax, x, y, title):
    ax.scatter(x, y, c=labels, s=10, alpha=0.7, cmap="Pastel1")
    ax.set_title(title)
    ax.set_xlabel("Comp 1")
    ax.set_ylabel("Comp 2")

# 1) 2D (comp1 vs comp2)
sc(axes[0], X2[:, 0], X2[:, 1], "2D projection (Comp1 vs Comp2)")

# 2) 3D projection: comp1 vs comp3
sc(axes[1], X3[:, 0], X3[:, 2], "3D proj (Comp1 vs Comp3)")

# 3) 3D projection: comp2 vs comp3
sc(axes[2], X3[:, 1], X3[:, 2], "3D proj (Comp2 vs Comp3)")

# 4) 2D + centroids
axes[3].scatter(X2[:, 0], X2[:, 1], c=labels, s=10, alpha=0.5, cmap="Pastel1")
axes[3].scatter(C2[:, 0], C2[:, 1], s=50, marker="X")
axes[3].set_title("2D + KMeans centroids")
axes[3].set_xlabel("Comp 1")
axes[3].set_ylabel("Comp 2")

# 5) 2D sampled
axes[4].scatter(X2[idx, 0], X2[idx, 1], c=np.asarray(labels)[idx], s=10, alpha=0.7, cmap="Pastel1")
axes[4].set_title(f"2D (sampled {sample_n:,})")
axes[4].set_xlabel("Comp 1")
axes[4].set_ylabel("Comp 2")

plt.tight_layout()
plt.show()

# %%
df_pc = pd.DataFrame(Z, columns=["PC1", "PC2", "PC3"], index=df_clean.loc[:, num.union(cat)].index)
df_tagged = df_clean.loc[:, num.union(cat)].loc[df_clean.loc[:, num.union(cat)].index].join(df_pc).assign(cluster=labels)
df_tagged.sort_values("PC2", ascending=False)[:10]
# Out:
#     account_type acct_status  age  allocated_amt brkg_type  brokerage_rate  \
# 4   THREE_IN_ONE           A   79          189.0       Low             7.0
# 21  THREE_IN_ONE           A   83       749375.0       Low             7.0
# 17  THREE_IN_ONE           A   70            NaN      High            29.0
# 15  THREE_IN_ONE           A   74       429887.0      High            29.0
# 20  THREE_IN_ONE           A   68            NaN       Low            10.0
# 18  THREE_IN_ONE           A   58         4426.0      High            29.0
# 5   THREE_IN_ONE           A   38            NaN       Low            15.0
# 1   THREE_IN_ONE           A   82            NaN       Low            10.0
# 6   THREE_IN_ONE           A   54          233.0      High            29.0
# 16  THREE_IN_ONE           A   64            NaN      High            22.0
#
#    brokerage_type education_desc  eq_total_assets eq_vertical  ...  \
# 4       APRM07007       GRADUATE              0.0      WEALTH  ...
# 21      PPSN07007  POST GRADUATE              0.0      WEALTH  ...
# 17         MSAVER  POST GRADUATE              0.0      WEALTH  ...
# 15         MSAVER  POST GRADUATE              0.0      WEALTH  ...
# 20      FPRMN1001  POST GRADUATE              0.0      ONLINE  ...
# 18         MSAVER  POST GRADUATE              0.0      ONLINE  ...
# 5       PPSN15015       GRADUATE              0.0      ONLINE  ...
# 1       FPRMN1001         OTHERS              0.0      SELECT  ...
# 6          MSAVER       GRADUATE              NaN      SELECT  ...
# 16      PRMN22022  POST GRADUATE              0.0      ONLINE  ...
#
#     peak_asset_val pincode_affluence ri_flag  scheme_code total_products  \
# 4     8.858123e+07         Very High       Y      Special           12.0
# 21    4.438431e+07         Very High       Y      Special            7.0
# 17    1.057839e+08         Very High       Y      Special            5.0
# 15    6.096317e+07         Very High       Y      Special           12.0
# 20    7.182258e+07         Very High       Y      Special           15.0
# 18    1.405889e+07         Very High       Y      Special            6.0
# 5     8.427340e+05         Very High       Y      Special            7.0
# 1     5.478719e+06         Very High       Y      Special            4.0
# 6     5.969920e+06         Very High       Y      Special            8.0
# 16    5.695794e+06         Very High       Y      Special           13.0
#
#    vertical_disg       PC1       PC2       PC3  cluster
# 4   PWM-PHYSICAL  2.701158  6.031067  0.224135        3
# 21  PWM-PHYSICAL  2.023306  5.461277 -1.448167        4
# 17  PWM-PHYSICAL  1.335780  4.949270  1.592882        3
# 15  PWM-PHYSICAL  1.868271  3.340769  0.694398        1
# 20    VIRTUAL RM  5.793431  2.450509  0.243545        3
# 18    VIRTUAL RM -0.905119  0.627176  0.077338        1
# 5         ONLINE -0.658590  0.539261 -1.911405        1
# 1     VIRTUAL RM  2.874877  0.179942 -4.244560        1
# 6     VIRTUAL RM -0.877242  0.178458  0.277771        1
# 16    VIRTUAL RM  2.112705  0.163315  0.549750        1
#
# [10 rows x 36 columns]

# %%
cluster_summary = df_tagged.groupby("cluster").mean(numeric_only=True)
feature_importance = (cluster_summary.max() - cluster_summary.min()).sort_values(ascending=False)
feature_importance[:10]
# Out:
# peak_asset_val       8.332653e+07
# neq_total_assets     6.877777e+07
# eq_total_assets      3.392531e+06
# allocated_amt        7.493570e+05
# no_of_logins         6.891250e+03
# no_logins_last_90    3.400000e+02
# experian_score       3.222000e+02
# no_logins_last_60    1.900000e+02
# no_logins_last_30    1.200000e+02
# income               4.520000e+01
# dtype: float64

# %%
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=pre.get_feature_names_out())
centroid_spread = (centroids.max() - centroids.min()).sort_values(ascending=False)
centroid_spread.iloc[:20]
# Out:
# num__eq_total_assets                 7.072541
# num__no_logins_last_30               6.567431
# num__no_logins_last_90               6.443868
# num__no_logins_last_60               6.339441
# num__allocated_amt                   6.196002
# num__no_of_logins                    6.070781
# num__mtf_rate                        4.885268
# num__peak_asset_val                  3.731035
# num__neq_total_assets                3.646901
# num__brokerage_rate                  3.455619
# num__income                          2.683977
# num__total_products                  2.150705
# num__age                             2.031032
# cat__gender_F                        1.000000
# cat__gender_M                        1.000000
# cat__marital_status_N                1.000000
# cat__education_desc_GRADUATE         1.000000
# cat__marital_status_Y                1.000000
# cat__education_desc_POST GRADUATE    1.000000
# cat__occupation_desc_OTHER           1.000000
# dtype: float64

# %%
silhouette_score(X, labels)
# Out:
# 0.09749444425797453

# %%
regressions = []
for feature in num.union(cat):
    from sklearn.linear_model import LinearRegression
    lr = LinearRegression()
    X_feat = df_tagged[[feature]].copy()
    # handle categorical features
    if feature in cat:
        X_feat = pd.get_dummies(X_feat, columns=[feature], drop_first=False)
    # drop rows with NaN
    mask = X_feat.notna().all(axis=1) & df_tagged["PC1"].notna()
    lr.fit(X_feat[mask], df_tagged.loc[mask, "PC1"])
    r2 = lr.score(X_feat[mask], df_tagged.loc[mask, "PC1"])
    regressions.append((feature, r2, lr.coef_))

regressions.sort(key=lambda x: x[1], reverse=True)
for feature, r2, coef in regressions[:10]:
    print(f"Feature: {feature}, R2: {r2:.2f}")
# Out:
# Feature: no_logins_last_30, R2: 0.90
# Feature: no_logins_last_60, R2: 0.89
# Feature: no_logins_last_90, R2: 0.88
# Feature: no_of_logins, R2: 0.82
# Feature: brokerage_type, R2: 0.71
# Feature: eq_total_assets, R2: 0.70
# Feature: brkg_type, R2: 0.46
# Feature: mtf_brkg, R2: 0.46
# Feature: mtf_rate, R2: 0.46
# Feature: brokerage_rate, R2: 0.42

# %%
# regression of each feature against PC1 sorted by highest correlation

regressions = []
for feature in num.union(cat):
    from sklearn.linear_model import LinearRegression
    lr = LinearRegression()
    X_feat = df_tagged[[feature]].copy()
    # handle categorical features
    if feature in cat:
        X_feat = pd.get_dummies(X_feat, columns=[feature], drop_first=False)
    # drop rows with NaN
    mask = X_feat.notna().all(axis=1) & df_tagged["PC2"].notna()
    lr.fit(X_feat[mask], df_tagged.loc[mask, "PC2"])
    r2 = lr.score(X_feat[mask], df_tagged.loc[mask, "PC2"])
    regressions.append((feature, r2, lr.coef_))

regressions.sort(key=lambda x: x[1], reverse=True)
for feature, r2, coef in regressions[:10]:
    print(f"Feature: {feature}, R2: {r2:.2f}")
# Out:
# Feature: income_segment, R2: 0.72
# Feature: peak_asset_val, R2: 0.69
# Feature: mtf_rate, R2: 0.60
# Feature: brokerage_type, R2: 0.55
# Feature: neq_total_assets, R2: 0.53
# Feature: allocated_amt, R2: 0.37
# Feature: vertical_disg, R2: 0.37
# Feature: eq_vertical, R2: 0.25
# Feature: age, R2: 0.25
# Feature: education_desc, R2: 0.21

# %%
regressions = []
for feature in num.union(cat):
    from sklearn.linear_model import LinearRegression
    lr = LinearRegression()
    X_feat = df_tagged[[feature]].copy()
    # handle categorical features
    if feature in cat:
        X_feat = pd.get_dummies(X_feat, columns=[feature], drop_first=False)
    # drop rows with NaN
    mask = X_feat.notna().all(axis=1) & df_tagged["PC3"].notna()
    lr.fit(X_feat[mask], df_tagged.loc[mask, "PC3"])
    r2 = lr.score(X_feat[mask], df_tagged.loc[mask, "PC3"])
    regressions.append((feature, r2, lr.coef_))

regressions.sort(key=lambda x: x[1], reverse=True)
for feature, r2, coef in regressions[:10]:
    print(f"Feature: {feature}, R2: {r2:.2f}")
# Out:
# Feature: experian_score, R2: 0.71
# Feature: occupation_desc, R2: 0.49
# Feature: mtf_rate, R2: 0.45
# Feature: brokerage_type, R2: 0.37
# Feature: income, R2: 0.32
# Feature: gender, R2: 0.28
# Feature: marital_status, R2: 0.26
# Feature: vertical_disg, R2: 0.25
# Feature: income_segment, R2: 0.24
# Feature: grade, R2: 0.23
